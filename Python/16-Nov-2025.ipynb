# %% [markdown]
# - Send email through Python
# - Take picture from Python
# - Start video call
# - Write the function
# - Boto3 Modules
# - Functions
# - We will create on App
# - We use smtplib library to send emails and it is a standard library which means it comes pre-installed.
# - Smtp library will be used to login into the gmail and the email library will be used to construct the email body.

# %%
import smtplib
from email.mime.text import MIMEText
sender = "aiopsboy@gmail.com"
# You cannot give the password directly, you need to generate an app password for your Gmail account and use it here.
# In case of app password, it does not require captcha verification, so it can be used in scripts and applications.
# Every time you change your Gmail password, you will need to generate a new app password and update it in your script. This is a security measure to protect your account.
password = "jtancrmvykruazyj"
recipient = "kumarnitildevops@gmail.com"
# recipient = ["kumarnitildevops@gmail.com", "anotherrecipient@gmail.com"]  # You can specify multiple recipients by providing a list of email addresses
subject = "Test Email from AiOpsBoy"
body = "This is a test email sent from a Python script using Gmail's SMTP server."
msg = MIMEText(body) # Create a MIMEText object to represent the email message
msg['subject'] = subject
msg['From'] = sender
msg['To'] = recipient
# Use the following format if you have multiple recipients:
# msg['To'] = ", ".join(recipient)  # Join the list of recipients
# Let us send the email using Gmail's SMTP server
# smtp.gmail.com is the SMTP server for Gmail, and 587 is the port number for TLS encryption.
with smtplib.SMTP('smtp.gmail.com', 587) as server:
    server.starttls() # Upgrade to a secure connection using TLS encryption
    server.login(sender, password)  # Log in to the SMTP server using the sender's email address and password
    server.send_message(msg)  # Send the email message
    # send to multiple recipients    # server.send_message(msg, from_addr=sender, to_addrs=recipient)  
    # # If you have multiple recipients, you can specify the sender and recipient addresses explicitly using the from_addr and
    print("Email sent successfully!")
# Out:
# Email sent successfully!

# %% [markdown]
# - Taking a photograph using Python
# - The image capture in Python can be done using two powerful libraries
# - OpenCV and PyGame
# - Open Source Computer Vision Library
# - Use import cv2

# %%
import cv2
print(dir(cv2))
print("\n")
print(hasattr(cv2, 'imwrite'))
cap = cv2.VideoCapture(0)
# There can be any number of cameras connected to your computer.
# The index of the camera is determined by the order in which they are connected.
# The first camera is usually indexed as 0, the second as 1, and so on.
# You have to specify the correct index for the camera you want to use. 
# If you have only one camera, it is usually indexed as 0. 
# If you have multiple cameras, you may need to try different indices (0, 1, 2, etc.) to find the correct one.
# We definitely need to check if the camera is opened successfully or not.
# Thus we need to use the if statement to check if the camera is opened successfully or not.
#if not cap.isOpened():
#    print("Error: Could not open camera.")
#    exit()
# cap.read() always returns two values: a boolean indicating whether the frame was read successfully, and the frame itself (which is an image).
# We need to check if the frame was read successfully before trying to display it.
ret, frame = cap.read()
# ret will get the boolean value and frame will get the image captured from the camera.
if ret:
    cv2.imwrite("captured_image.jpg", frame) 
    print ("PHoto is stored")
else:
    print("Error: Could not read frame from camera.")
cap.release() # Release the camera resource when done
# Out:
# ['ACCESS_FAST', 'ACCESS_MASK', 'ACCESS_READ', 'ACCESS_RW', 'ACCESS_WRITE', 'ADAPTIVE_THRESH_GAUSSIAN_C', 'ADAPTIVE_THRESH_MEAN_C', 'AGAST_FEATURE_DETECTOR_AGAST_5_8', 'AGAST_FEATURE_DETECTOR_AGAST_7_12D', 'AGAST_FEATURE_DETECTOR_AGAST_7_12S', 'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION', 'AGAST_FEATURE_DETECTOR_OAST_9_16', 'AGAST_FEATURE_DETECTOR_THRESHOLD', 'AKAZE', 'AKAZE_DESCRIPTOR_KAZE', 'AKAZE_DESCRIPTOR_KAZE_UPRIGHT', 'AKAZE_DESCRIPTOR_MLDB', 'AKAZE_DESCRIPTOR_MLDB_UPRIGHT', 'AKAZE_create', 'AffineFeature', 'AffineFeature_create', 'AffineTransformer', 'AgastFeatureDetector', 'AgastFeatureDetector_AGAST_5_8', 'AgastFeatureDetector_AGAST_7_12d', 'AgastFeatureDetector_AGAST_7_12s', 'AgastFeatureDetector_NONMAX_SUPPRESSION', 'AgastFeatureDetector_OAST_9_16', 'AgastFeatureDetector_THRESHOLD', 'AgastFeatureDetector_create', 'Algorithm', 'AlignExposures', 'AlignMTB', 'AsyncArray', 'BFMatcher', 'BFMatcher_create', 'BORDER_CONSTANT', 'BORDER_DEFAULT', 'BORDER_ISOLATED', 'BORDER_REFLECT',
# ...

# %% [markdown]
# - Taking input from the user
# - In python we use the inbuilt function called as **input**

# %%
key = input("Enter a key to exit: ")
if int(key) > 10:
    print("Execute the job")
else:
    print("Exit the job")
# Out:
# Exit the job

# %% [markdown]
# - For loop is simple to iterate in python
# - We can always add characters to the output in the print statement as shown below.

# %%
db = ["tom", "jerry", "spike", "tyke", "butch"]
for i in db:
    print(i)
# Adding the email addresses to the list
for i in db:
    print(i + "@gmail.com")
db2 = []
for i in db:
    db2.append(i + "@gmail.com")
print(db2)
# Out:
# tom
# jerry
# spike
# tyke
# butch
# tom@gmail.com
# jerry@gmail.com
# spike@gmail.com
# tyke@gmail.com
# butch@gmail.com
# ['tom@gmail.com', 'jerry@gmail.com', 'spike@gmail.com', 'tyke@gmail.com', 'butch@gmail.com']
