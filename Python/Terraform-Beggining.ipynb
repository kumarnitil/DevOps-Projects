# %% [markdown]
# # Terraform
# - .tf file is the extension of the terraform file.
# - First we have to connect terraform to my AWS Account.
# - The account credentials are mentioned in the provider.tf
# - Go to terraform registry to see how many types of clouds it can install
# - name and tag
# - instance type
# - Networking
# - Key Pair
# - Resources - When you need to create something from Scratch
# - Data Sources - Already present on the console. Example - Using a security group present in cloud console.
# - aws_instance
# - caf - Cloud Adoption Framework
# - ec2-hypha-dev-appec02
# - The minimum required can be checked in the documentation
# - Terraform init
# - Terraform plan
# - Terraform apply
# - Terraform can update the same resource but boto3 can create resource
# - terraform.tfstate is the file which terraform uses to check the states of the resources.
# - instance id - it will used to recognize
# - run the command **terraform fmt** to correct th indentation of all the files in that folder
# - In case of AWS we will store the state file in the S3 bucket
# - Enable Bucket versioning to make sure it can be secured
