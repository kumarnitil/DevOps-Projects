# %% [markdown]
# # BOTO-3 Library and its implementation
# - Import the Boto 3 Library.
# - The best way is to start from the - https://docs.aws.amazon.com/boto3/latest/
# - The code to create an ec2 instance would be running somewhere in your local machine.
# - But in order to create the that you need access key and secret key and the region of AWS where this intsance will be created.
# - access Key, secret key and Region = aws_access_key_id for boto3 - https://docs.aws.amazon.com/boto3/latest/guide/credentials.html
# - Region which is specified in the page - https://docs.aws.amazon.com/boto3/latest/reference/services/ec2/client/describe_regions.html
# - Block device instance is added when we have in the configuration when you have to add EBS Volume to your EC2 instance.
# - https://docs.aws.amazon.com/boto3/latest/reference/services/ec2/service-resource/create_instances.html
# - BlockDeviceMappings=[
#         {
#             'Ebs': {
#                 'DeleteOnTermination': True|False, # Do we terminate the volume when the EC2 instance is terminated.
#                 'Iops': 123,
#                 'SnapshotId': 'string',
#                 'VolumeSize': 123,
#                 'VolumeType': 'standard'|'io1'|'io2'|'gp2'|'sc1'|'st1'|'gp3',
#                 'KmsKeyId': 'string', # KMS Key is the encryption
#                 'Throughput': 123,
#                 'OutpostArn': 'string',
#                 'AvailabilityZone': 'string',
#                 'Encrypted': True|False,
#                 'VolumeInitializationRate': 123,
#                 'AvailabilityZoneId': 'string',
#                 'EbsCardIndex': 123
#             },
#             'NoDevice': 'string',
#             'DeviceName': 'string',
#             'VirtualName': 'string'
#         },
#     ],

# %%
import boto3
AWS_ACCESS_KEY_ID = "AKIA3HUEDYMPFM3S6UTL"
AWS_SECRET_ACCESS_KEY = "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"
REGION = "us-east-1"
# Apart from the Access key and Secret key, you can also specify the region_name parameter if you want to connect to a specific AWS region.
# Thus it is a good practice to specify the region_name parameter when creating the client,
# especially if you are working with resources that are region-specific.
# If you specify region as well as a variable for the region so that you can change the region easily, you can do it like this:

client = boto3.client('ec2', aws_access_key_id=AWS_ACCESS_KEY_ID, aws_secret_access_key=AWS_SECRET_ACCESS_KEY, region_name = REGION, )
instance = ec2.create_instances(
    ImageId='string', # The ImageId parameter specifies the ID of the Amazon Machine Image (AMI) to use when launching an instance. An AMI is a pre-configured virtual machine image that contains the operating system, application server, and applications required to launch an instance. The ImageId parameter is required when launching an instance, and it must be a valid AMI ID that is available in the region where you are launching the instance.
    InstanceType='string', # The InstanceType parameter specifies the type of instance to launch. It determines the hardware of the host computer used for your instance. Each instance type offers different compute, memory, and storage capabilities. For example, you can choose an instance type that is optimized for compute-intensive workloads, memory-intensive workloads, or storage-intensive workloads. The InstanceType parameter is required when launching an instance.
    MaxCount=2, # The MaxCount parameter specifies the maximum number of instances to launch. It is used in conjunction with the MinCount parameter, which specifies the minimum number of instances to launch. The MaxCount parameter ensures that you do not launch more instances than you intend to, while the MinCount parameter ensures that you launch at least a certain number of instances. 
    MinCount=1, # The MinCount parameter specifies the minimum number of instances to launch. It is used in conjunction with the MaxCount parameter, which specifies the maximum number of instances to launch. The MinCount parameter ensures that you launch at least a certain number of instances, while the MaxCount parameter ensures that you do not launch more instances than you intend to.
    SecurityGroupIds=[ # The SecurityGroupIds parameter specifies the IDs of the security groups to associate with the instance. A security group acts as a virtual firewall for your instance to control inbound and outbound traffic. You can specify one or more security group IDs in this parameter, and the instance will be associated with all of the specified security groups. If you do not specify any security group IDs, the instance will be associated with the default security group for the VPC.
        'string',
    ],
)
